# %% [markdown]
# <a href="https://colab.research.google.com/github/Oseiasdfarias/Modelagem_e_Simulacao_de_Sistemas/blob/main/controle_de_altitude_drone.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Modelagem Drone Quadrotor

# %% [markdown]
# ![quadcopter-design-pdf.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Análise do Sistema no Domínio da Frequência

# %% [markdown]
# # Projeto de um Controlador de Altitude
